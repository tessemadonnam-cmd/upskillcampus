# %% [markdown]
# <a href="https://colab.research.google.com/github/tessemadonnam-cmd/upskillcampus/blob/main/BankingInformationSystem_java.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile BankingInformationSystem.java
#
# import java.util.ArrayList;
# import java.util.Scanner;
#
# class BankAccount {
#     private String accountHolder;
#     private int accountNumber;
#     private double balance;
#
#     public BankAccount(String accountHolder, int accountNumber, double balance) {
#         this.accountHolder = accountHolder;
#         this.accountNumber = accountNumber;
#         this.balance = balance;
#     }
#
#     public int getAccountNumber() {
#         return accountNumber;
#     }
#
#     public void deposit(double amount) {
#         balance += amount;
#         System.out.println("₹" + amount + " deposited successfully.");
#     }
#
#     public void withdraw(double amount) {
#         if (amount > balance) {
#             System.out.println("Insufficient Balance!");
#         } else {
#             balance -= amount;
#             System.out.println("₹" + amount + " withdrawn successfully.");
#         }
#     }
#
#     public void displayDetails() {
#         System.out.println("\n-------------------------");
#         System.out.println("Account Holder : " + accountHolder);
#         System.out.println("Account Number : " + accountNumber);
#         System.out.println("Balance        : ₹" + balance);
#         System.out.println("-------------------------");
#     }
# }
#
# public class BankingInformationSystem {
#
#     public static BankAccount findAccount(ArrayList<BankAccount> accounts, int accNo) {
#         for (BankAccount account : accounts) {
#             if (account.getAccountNumber() == accNo) {
#                 return account;
#             }
#         }
#         return null;
#     }
#
#     public static void main(String[] args) {
#
#         Scanner sc = new Scanner(System.in);
#         ArrayList<BankAccount> accounts = new ArrayList<>();
#
#         int choice;
#
#         do {
#             System.out.println("\n===== BANKING INFORMATION SYSTEM =====");
#             System.out.println("1. Create Account");
#             System.out.println("2. Deposit Money");
#             System.out.println("3. Withdraw Money");
#             System.out.println("4. View Account Details");
#             System.out.println("5. Exit");
#             System.out.print("Enter Choice: ");
#
#             choice = sc.nextInt();
#
#             switch (choice) {
#
#                 case 1:
#                     sc.nextLine();
#
#                     System.out.print("Enter Account Holder Name: ");
#                     String name = sc.nextLine();
#
#                     System.out.print("Enter Account Number: ");
#                     int accNo = sc.nextInt();
#
#                     System.out.print("Enter Initial Balance: ");
#                     double balance = sc.nextDouble();
#
#                     accounts.add(new BankAccount(name, accNo, balance));
#
#                     System.out.println("Account Created Successfully!");
#                     break;
#
#                 case 2:
#                     System.out.print("Enter Account Number: ");
#                     accNo = sc.nextInt();
#
#                     BankAccount depositAcc = findAccount(accounts, accNo);
#
#                     if (depositAcc != null) {
#                         System.out.print("Enter Deposit Amount: ");
#                         double amount = sc.nextDouble();
#                         depositAcc.deposit(amount);
#                     } else {
#                         System.out.println("Account Not Found!");
#                     }
#                     break;
#
#                 case 3:
#                     System.out.print("Enter Account Number: ");
#                     accNo = sc.nextInt();
#
#                     BankAccount withdrawAcc = findAccount(accounts, accNo);
#
#                     if (withdrawAcc != null) {
#                         System.out.print("Enter Withdrawal Amount: ");
#                         double amount = sc.nextDouble();
#                         withdrawAcc.withdraw(amount);
#                     } else {
#                         System.out.println("Account Not Found!");
#                     }
#                     break;
#
#                 case 4:
#                     System.out.print("Enter Account Number: ");
#                     accNo = sc.nextInt();
#
#                     BankAccount viewAcc = findAccount(accounts, accNo);
#
#                     if (viewAcc != null) {
#                         viewAcc.displayDetails();
#                     } else {
#                         System.out.println("Account Not Found!");
#                     }
#                     break;
#
#                 case 5:
#                     System.out.println("Thank You For Using Banking Information System!");
#                     break;
#
#                 default:
#                     System.out.println("Invalid Choice!");
#             }
#
#         } while (choice != 5);
#
#         sc.close();
#     }
# }
# Out:
# Overwriting BankingInformationSystem.java

# %%
# !javac BankingInformationSystem.java

# %%
# !java BankingInformationSystem
# Out:
# ===== BANKING INFORMATION SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. View Account Details
# 5. Exit
# Enter Choice: 1
# Enter Account Holder Name: Madonna
# Enter Account Number: 2399
# Enter Initial Balance: 170000
# Account Created Successfully!
#
# ===== BANKING INFORMATION SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. View Account Details
# 5. Exit
# Enter Choice: 4
# Enter Account Number: 2399
#
# -------------------------
# Account Holder : Madonna
# Account Number : 2399
# Balance        : ₹170000.0
# -------------------------
#
# ===== BANKING INFORMATION SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. View Account Details
# 5. Exit
# Enter Choice:
